# %% [markdown]
# <a href="https://colab.research.google.com/github/thanunjayramaib4079-ThanunjayRam/2025-26-4079-THANUNJAYRAM-AI-B-DS/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#linear search
n = int(input("enter no. of elements:"))
arr = []

for i in range(n):
    arr.append(int(input(f"enter element {i}:")))

key = int(input("enter element to search:"))

found = False

for i in range(n):
    if arr[i] == key:
        print(f"element {key} found at position {i+1}")
        foond = True
        break

if not foond:
    print("element not found:")
# Out:
# enter no. of elements:5
# enter element 0:1
# enter element 1:2
# enter element 2:3
# enter element 3:4
# enter element 4:5
# enter element to search:2
# element 2 found at position 2

# %%
# Bubble sort
n = int(input("Enter number of elements: "))

arr = []

for i in range(n):
    arr.append(int(input(f"Enter element {i+1}: ")))

print("\nOriginal array:", arr)

# Bubble sort logic
for i in range(n-1):
    for j in range(n-1-i):
        if arr[j] > arr[j+1]:
            # Swap
            arr[j], arr[j+1] = arr[j+1], arr[j]

print("Sorted array:", arr)
# Out:
# Enter number of elements: 5
# Enter element 1: 2
# Enter element 2: 5
# Enter element 3: 4
# Enter element 4: 1
# Enter element 5: 3
#
# Original array: [2, 5, 4, 1, 3]
# Sorted array: [1, 2, 3, 4, 5]

# %%
# Selection sort
n = int(input("enter number of elements:"))

arr = []

for i in range(n):
    arr.append(int(input(f"enter element {i+1}:")))

print("\n Original array:", arr)

# selection sort logic
for i in range(n-1):
    min_index = i
    for j in range(i+1, n):
        if arr[j] < arr[min_index]:
            min_index = j

    # swap found min element with first element
    arr[i], arr[min_index] = arr[min_index], arr[i]

print("sorted array:", arr)
# Out:
# enter number of elements:5
# enter element 1:2
# enter element 2:3
# enter element 3:4
# enter element 4:5
# enter element 5:6
#
#  Original array: [2, 3, 4, 5, 6]
# sorted array: [2, 3, 4, 5, 6]
